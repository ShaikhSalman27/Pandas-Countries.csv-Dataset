# %%
import pandas as pd

# %%
countries_df = pd.read_csv('countries.csv')
countries_df
# Out:
#       id                       name iso3 iso2  numeric_code phone_code  \
# 0      1                Afghanistan  AFG   AF             4         93
# 1      2              Aland Islands  ALA   AX           248    +358-18
# 2      3                    Albania  ALB   AL             8        355
# 3      4                    Algeria  DZA   DZ            12        213
# 4      5             American Samoa  ASM   AS            16     +1-684
# ..   ...                        ...  ...  ...           ...        ...
# 245  243  Wallis And Futuna Islands  WLF   WF           876        681
# 246  244             Western Sahara  ESH   EH           732        212
# 247  245                      Yemen  YEM   YE           887        967
# 248  246                     Zambia  ZMB   ZM           894        260
# 249  247                   Zimbabwe  ZWE   ZW           716        263
#
#        capital currency    currency_name currency_symbol  ...   region  \
# 0        Kabul      AFN   Afghan afghani               ؋  ...     Asia
# 1    Mariehamn      EUR             Euro               €  ...   Europe
# 2       Tirana      ALL     Albanian lek             Lek  ...   Europe
# 3      Algiers      DZD   Algerian dinar              دج  ...   Africa
# 4    Pago Pago      USD        US Dollar               $  ...  Oceania
# ..         ...      ...              ...             ...  ...      ...
# 245   Mata Utu      XPF        CFP franc               ₣  ...  Oceania
# 246   El-Aaiun      MAD  Moroccan Dirham             MAD  ...   Africa
# 247      Sanaa      YER      Yemeni rial               ﷼  ...     Asia
# 248     Lusaka      ZMW   Zambian kwacha              ZK  ...   Africa
# 249     Harare      ZWL  Zimbabwe Dollar               $  ...   Africa
#
#     region_id        subregion  subregion_id  \
# 0         3.0    Southern Asia          14.0
# 1         4.0  Northern Europe          18.0
# 2         4.0  Southern Europe          16.0
# 3         1.0  Northern Africa           1.0
# 4         5.0        Polynesia          22.0
# ..        ...              ...           ...
# 245       5.0        Polynesia          22.0
# 246       1.0  Northern Africa           1.0
# 247       3.0     Western Asia          11.0
# 248       1.0   Eastern Africa           4.0
# 249       1.0   Eastern Africa           4.0
#
#                                  nationality  \
# 0                                     Afghan
# 1                               Aland Island
# 2                                  Albanian
# 3                                   Algerian
# 4                            American Samoan
# ..                                       ...
# 245  Wallis and Futuna, Wallisian or Futunan
# 246           Sahrawi, Sahrawian, Sahraouian
# 247                                   Yemeni
# 248                                  Zambian
# 249                               Zimbabwean
#
#                                              timezones   latitude longitude  \
# 0    [{zoneName:'Asia\/Kabul',gmtOffset:16200,gmtOf...  33.000000      65.0
# 1    [{zoneName:'Europe\/Mariehamn',gmtOffset:7200,...  60.116667      19.9
# 2    [{zoneName:'Europe\/Tirane',gmtOffset:3600,gmt...  41.000000      20.0
# 3    [{zoneName:'Africa\/Algiers',gmtOffset:3600,gm...  28.000000       3.0
# 4    [{zoneName:'Pacific\/Pago_Pago',gmtOffset:-396... -14.333333    -170.0
# ..                                                 ...        ...       ...
# 245  [{zoneName:'Pacific\/Wallis',gmtOffset:43200,g... -13.300000    -176.2
# 246  [{zoneName:'Africa\/El_Aaiun',gmtOffset:3600,g...  24.500000     -13.0
# 247  [{zoneName:'Asia\/Aden',gmtOffset:10800,gmtOff...  15.000000      48.0
# 248  [{zoneName:'Africa\/Lusaka',gmtOffset:7200,gmt... -15.000000      30.0
# 249  [{zoneName:'Africa\/Harare',gmtOffset:7200,gmt... -20.000000      30.0
#
#      emoji           emojiU
# 0       🇦🇫  U+1F1E6 U+1F1EB
# 1       🇦🇽  U+1F1E6 U+1F1FD
# 2       🇦🇱  U+1F1E6 U+1F1F1
# 3       🇩🇿  U+1F1E9 U+1F1FF
# 4       🇦🇸  U+1F1E6 U+1F1F8
# ..     ...              ...
# 245     🇼🇫  U+1F1FC U+1F1EB
# 246     🇪🇭  U+1F1EA U+1F1ED
# 247     🇾🇪  U+1F1FE U+1F1EA
# 248     🇿🇲  U+1F1FF U+1F1F2
# 249     🇿🇼  U+1F1FF U+1F1FC
#
# [250 rows x 22 columns]

# %%
countries_df.shape
# Out:
# (250, 22)

# %%
num_countries = countries_df.shape
print(f'There are {num_countries} in dataset')
# Out:
# There are (250, 22) in dataset

# %%
num_countrie = countries_df.name
num_countrie
# Out:
# 0                    Afghanistan
# 1                  Aland Islands
# 2                        Albania
# 3                        Algeria
# 4                 American Samoa
#                  ...
# 245    Wallis And Futuna Islands
# 246               Western Sahara
# 247                        Yemen
# 248                       Zambia
# 249                     Zimbabwe
# Name: name, Length: 250, dtype: object

# %%
print(f'{num_countrie} in dataset')
# Out:
# 0                    Afghanistan
# 1                  Aland Islands
# 2                        Albania
# 3                        Algeria
# 4                 American Samoa
#                  ...
# 245    Wallis And Futuna Islands
# 246               Western Sahara
# 247                        Yemen
# 248                       Zambia
# 249                     Zimbabwe
# Name: name, Length: 250, dtype: object in dataset

# %%
# retrieve a list of contents from the dataset?

continents = countries_df.columns
continents
# Out:
# Index(['id', 'name', 'iso3', 'iso2', 'numeric_code', 'phone_code', 'capital',
#        'currency', 'currency_name', 'currency_symbol', 'tld', 'native',
#        'region', 'region_id', 'subregion', 'subregion_id', 'nationality',
#        'timezones', 'latitude', 'longitude', 'emoji', 'emojiU'],
#       dtype='object')

# %%
# what is the total latitude of all the listed in the dataset

total_latitude = countries_df.latitude.sum()
print(f'The total latitude is {total_latitude}')
# Out:
# The total latitude is 4100.649341130001

# %%
# what is the overall life expectaion in the world

life_expect_mean = countries_df.latitude.mean()
life_expect_median = countries_df.latitude.median()

print(f'life expectation of mean {life_expect_mean} and meadian {life_expect_median}')
# Out:
# life expectation of mean 16.402597364520002 and meadian 16.083333330000002

# %%
# 10 highest countries latitude

most_latitude_df = countries_df.sort_values('latitude', ascending=False).head(10)
most_latitude_df
# Out:
#       id                            name iso3 iso2  numeric_code phone_code  \
# 212  211  Svalbard And Jan Mayen Islands  SJM   SJ           744         47
# 86    86                       Greenland  GRL   GL           304        299
# 100  100                         Iceland  ISL   IS           352        354
# 74    74                         Finland  FIN   FI           246        358
# 214  213                          Sweden  SWE   SE           752         46
# 72    72                   Faroe Islands  FRO   FO           234        298
# 164  165                          Norway  NOR   NO           578         47
# 1      2                   Aland Islands  ALA   AX           248    +358-18
# 38    39                          Canada  CAN   CA           124          1
# 181  182                          Russia  RUS   RU           643          7
#
#           capital currency    currency_name currency_symbol  ...    region  \
# 212  Longyearbyen      NOK  Norwegian Krone              kr  ...    Europe
# 86           Nuuk      DKK     Danish krone             Kr.  ...  Americas
# 100     Reykjavik      ISK  Icelandic króna              kr  ...    Europe
# 74       Helsinki      EUR             Euro               €  ...    Europe
# 214     Stockholm      SEK    Swedish krona              kr  ...    Europe
# 72       Torshavn      DKK     Danish krone             Kr.  ...    Europe
# 164          Oslo      NOK  Norwegian krone              kr  ...    Europe
# 1       Mariehamn      EUR             Euro               €  ...    Europe
# 38         Ottawa      CAD  Canadian dollar               $  ...  Americas
# 181        Moscow      RUB    Russian ruble               ₽  ...    Europe
#
#     region_id         subregion  subregion_id   nationality  \
# 212       4.0   Northern Europe          18.0      Svalbard
# 86        2.0  Northern America           6.0   Greenlandic
# 100       4.0   Northern Europe          18.0     Icelandic
# 74        4.0   Northern Europe          18.0       Finnish
# 214       4.0   Northern Europe          18.0       Swedish
# 72        4.0   Northern Europe          18.0       Faroese
# 164       4.0   Northern Europe          18.0     Norwegian
# 1         4.0   Northern Europe          18.0  Aland Island
# 38        2.0  Northern America           6.0      Canadian
# 181       4.0    Eastern Europe          15.0       Russian
#
#                                              timezones   latitude longitude  \
# 212  [{zoneName:'Arctic\/Longyearbyen',gmtOffset:36...  78.000000      20.0
# 86   [{zoneName:'America\/Danmarkshavn',gmtOffset:0...  72.000000     -40.0
# 100  [{zoneName:'Atlantic\/Reykjavik',gmtOffset:0,g...  65.000000     -18.0
# 74   [{zoneName:'Europe\/Helsinki',gmtOffset:7200,g...  64.000000      26.0
# 214  [{zoneName:'Europe\/Stockholm',gmtOffset:3600,...  62.000000      15.0
# 72   [{zoneName:'Atlantic\/Faroe',gmtOffset:0,gmtOf...  62.000000      -7.0
# 164  [{zoneName:'Europe\/Oslo',gmtOffset:3600,gmtOf...  62.000000      10.0
# 1    [{zoneName:'Europe\/Mariehamn',gmtOffset:7200,...  60.116667      19.9
# 38   [{zoneName:'America\/Atikokan',gmtOffset:-1800...  60.000000     -95.0
# 181  [{zoneName:'Asia\/Anadyr',gmtOffset:43200,gmtO...  60.000000     100.0
#
#      emoji           emojiU
# 212     🇸🇯  U+1F1F8 U+1F1EF
# 86      🇬🇱  U+1F1EC U+1F1F1
# 100     🇮🇸  U+1F1EE U+1F1F8
# 74      🇫🇮  U+1F1EB U+1F1EE
# 214     🇸🇪  U+1F1F8 U+1F1EA
# 72      🇫🇴  U+1F1EB U+1F1F4
# 164     🇳🇴  U+1F1F3 U+1F1F4
# 1       🇦🇽  U+1F1E6 U+1F1FD
# 38      🇨🇦  U+1F1E8 U+1F1E6
# 181     🇷🇺  U+1F1F7 U+1F1FA
#
# [10 rows x 22 columns]

# %%
countries_df['gdp'] = countries_df.longitude / countries_df.latitude
countries_df
# Out:
#       id                       name iso3 iso2  numeric_code phone_code  \
# 0      1                Afghanistan  AFG   AF             4         93
# 1      2              Aland Islands  ALA   AX           248    +358-18
# 2      3                    Albania  ALB   AL             8        355
# 3      4                    Algeria  DZA   DZ            12        213
# 4      5             American Samoa  ASM   AS            16     +1-684
# ..   ...                        ...  ...  ...           ...        ...
# 245  243  Wallis And Futuna Islands  WLF   WF           876        681
# 246  244             Western Sahara  ESH   EH           732        212
# 247  245                      Yemen  YEM   YE           887        967
# 248  246                     Zambia  ZMB   ZM           894        260
# 249  247                   Zimbabwe  ZWE   ZW           716        263
#
#        capital currency    currency_name currency_symbol  ... region_id  \
# 0        Kabul      AFN   Afghan afghani               ؋  ...       3.0
# 1    Mariehamn      EUR             Euro               €  ...       4.0
# 2       Tirana      ALL     Albanian lek             Lek  ...       4.0
# 3      Algiers      DZD   Algerian dinar              دج  ...       1.0
# 4    Pago Pago      USD        US Dollar               $  ...       5.0
# ..         ...      ...              ...             ...  ...       ...
# 245   Mata Utu      XPF        CFP franc               ₣  ...       5.0
# 246   El-Aaiun      MAD  Moroccan Dirham             MAD  ...       1.0
# 247      Sanaa      YER      Yemeni rial               ﷼  ...       3.0
# 248     Lusaka      ZMW   Zambian kwacha              ZK  ...       1.0
# 249     Harare      ZWL  Zimbabwe Dollar               $  ...       1.0
#
#            subregion subregion_id                              nationality  \
# 0      Southern Asia         14.0                                   Afghan
# 1    Northern Europe         18.0                             Aland Island
# 2    Southern Europe         16.0                                Albanian
# 3    Northern Africa          1.0                                 Algerian
# 4          Polynesia         22.0                          American Samoan
# ..               ...          ...                                      ...
# 245        Polynesia         22.0  Wallis and Futuna, Wallisian or Futunan
# 246  Northern Africa          1.0           Sahrawi, Sahrawian, Sahraouian
# 247     Western Asia         11.0                                   Yemeni
# 248   Eastern Africa          4.0                                  Zambian
# 249   Eastern Africa          4.0                               Zimbabwean
#
#                                              timezones   latitude longitude  \
# 0    [{zoneName:'Asia\/Kabul',gmtOffset:16200,gmtOf...  33.000000      65.0
# 1    [{zoneName:'Europe\/Mariehamn',gmtOffset:7200,...  60.116667      19.9
# 2    [{zoneName:'Europe\/Tirane',gmtOffset:3600,gmt...  41.000000      20.0
# 3    [{zoneName:'Africa\/Algiers',gmtOffset:3600,gm...  28.000000       3.0
# 4    [{zoneName:'Pacific\/Pago_Pago',gmtOffset:-396... -14.333333    -170.0
# ..                                                 ...        ...       ...
# 245  [{zoneName:'Pacific\/Wallis',gmtOffset:43200,g... -13.300000    -176.2
# 246  [{zoneName:'Africa\/El_Aaiun',gmtOffset:3600,g...  24.500000     -13.0
# 247  [{zoneName:'Asia\/Aden',gmtOffset:10800,gmtOff...  15.000000      48.0
# 248  [{zoneName:'Africa\/Lusaka',gmtOffset:7200,gmt... -15.000000      30.0
# 249  [{zoneName:'Africa\/Harare',gmtOffset:7200,gmt... -20.000000      30.0
#
#     emoji           emojiU        gdp
# 0      🇦🇫  U+1F1E6 U+1F1EB   1.969697
# 1      🇦🇽  U+1F1E6 U+1F1FD   0.331023
# 2      🇦🇱  U+1F1E6 U+1F1F1   0.487805
# 3      🇩🇿  U+1F1E9 U+1F1FF   0.107143
# 4      🇦🇸  U+1F1E6 U+1F1F8  11.860465
# ..    ...              ...        ...
# 245    🇼🇫  U+1F1FC U+1F1EB  13.248120
# 246    🇪🇭  U+1F1EA U+1F1ED  -0.530612
# 247    🇾🇪  U+1F1FE U+1F1EA   3.200000
# 248    🇿🇲  U+1F1FF U+1F1F2  -2.000000
# 249    🇿🇼  U+1F1FF U+1F1FC  -1.500000
#
# [250 rows x 23 columns]

# %%
lowest_gdp = countries_df.sort_values('gdp', ascending=True)
lowest_gdp
# Out:
#       id                                  name iso3 iso2  numeric_code  \
# 151  153                                 Nauru  NRU   NR           520
# 170  171                      Papua new Guinea  PNG   PG           598
# 102  102                             Indonesia  IDN   ID           360
# 230  228                                Tuvalu  TUV   TV           798
# 202  202                       Solomon Islands  SLB   SB            90
# ..   ...                                   ...  ...  ...           ...
# 130  132                              Malaysia  MYS   MY           458
# 198  199                             Singapore  SGP   SG           702
# 114  114                              Kiribati  KIR   KI           296
# 58    51      Democratic Republic of the Congo  COD   CD           180
# 236  234  United States Minor Outlying Islands  UMI   UM           581
#
#     phone_code       capital currency           currency_name currency_symbol  \
# 151        674         Yaren      AUD       Australian dollar               $
# 170        675  Port Moresby      PGK  Papua New Guinean kina               K
# 102         62       Jakarta      IDR       Indonesian rupiah              Rp
# 230        688      Funafuti      AUD       Australian dollar               $
# 202        677       Honiara      SBD  Solomon Islands dollar             Si$
# ..         ...           ...      ...                     ...             ...
# 130         60  Kuala Lumpur      MYR       Malaysian ringgit              RM
# 198         65      Singapur      SGD        Singapore dollar               $
# 114        686        Tarawa      AUD       Australian dollar               $
# 58         243      Kinshasa      CDF         Congolese Franc              FC
# 236          1           NaN      USD    United States dollar               $
#
#      ... region_id           subregion subregion_id  \
# 151  ...       5.0          Micronesia         21.0
# 170  ...       5.0           Melanesia         20.0
# 102  ...       3.0  South-Eastern Asia         13.0
# 230  ...       5.0           Polynesia         22.0
# 202  ...       5.0           Melanesia         20.0
# ..   ...       ...                 ...          ...
# 130  ...       3.0  South-Eastern Asia         13.0
# 198  ...       3.0  South-Eastern Asia         13.0
# 114  ...       5.0          Micronesia         21.0
# 58   ...       1.0       Middle Africa          2.0
# 236  ...       2.0    Northern America          6.0
#
#                    nationality  \
# 151                    Nauruan
# 170  Papua New Guinean, Papuan
# 102                 Indonesian
# 230                   Tuvaluan
# 202             Solomon Island
# ..                         ...
# 130                  Malaysian
# 198                Singaporean
# 114                 I-Kiribati
# 58                   Congolese
# 236                   American
#
#                                              timezones  latitude   longitude  \
# 151  [{zoneName:'Pacific\/Nauru',gmtOffset:43200,gm... -0.533333  166.916667
# 170  [{zoneName:'Pacific\/Bougainville',gmtOffset:3... -6.000000  147.000000
# 102  [{zoneName:'Asia\/Jakarta',gmtOffset:25200,gmt... -5.000000  120.000000
# 230  [{zoneName:'Pacific\/Funafuti',gmtOffset:43200... -8.000000  178.000000
# 202  [{zoneName:'Pacific\/Guadalcanal',gmtOffset:39... -8.000000  159.000000
# ..                                                 ...       ...         ...
# 130  [{zoneName:'Asia\/Kuala_Lumpur',gmtOffset:2880...  2.500000  112.500000
# 198  [{zoneName:'Asia\/Singapore',gmtOffset:28800,g...  1.366667  103.800000
# 114  [{zoneName:'Pacific\/Enderbury',gmtOffset:4680...  1.416667  173.000000
# 58   [{zoneName:'Africa\/Kinshasa',gmtOffset:3600,g...  0.000000   25.000000
# 236  [{zoneName:'Pacific\/Midway',gmtOffset:-39600,...  0.000000    0.000000
#
#     emoji           emojiU         gdp
# 151    🇳🇷  U+1F1F3 U+1F1F7 -312.968752
# 170    🇵🇬  U+1F1F5 U+1F1EC  -24.500000
# 102    🇮🇩  U+1F1EE U+1F1E9  -24.000000
# 230    🇹🇻  U+1F1F9 U+1F1FB  -22.250000
# 202    🇸🇧  U+1F1F8 U+1F1E7  -19.875000
# ..    ...              ...         ...
# 130    🇲🇾  U+1F1F2 U+1F1FE   45.000000
# 198    🇸🇬  U+1F1F8 U+1F1EC   75.951220
# 114    🇰🇮  U+1F1F0 U+1F1EE  122.117648
# 58     🇨🇩  U+1F1E8 U+1F1E9         inf
# 236    🇺🇲  U+1F1FA U+1F1F2         NaN
#
# [250 rows x 23 columns]

# %%
# Creat the data frame that counts the numbers countries in each continent?

countries_count_df = countries_df.groupby('name')[['region_id', 'subregion_id', 'latitude', 'longitude']].count()
countries_count_df
# Out:
#                            region_id  subregion_id  latitude  longitude
# name
# Afghanistan                        1             1         1          1
# Aland Islands                      1             1         1          1
# Albania                            1             1         1          1
# Algeria                            1             1         1          1
# American Samoa                     1             1         1          1
# ...                              ...           ...       ...        ...
# Wallis And Futuna Islands          1             1         1          1
# Western Sahara                     1             1         1          1
# Yemen                              1             1         1          1
# Zambia                             1             1         1          1
# Zimbabwe                           1             1         1          1
#
# [250 rows x 4 columns]

# %%
countries_df_sum = countries_df.groupby('name')[['region_id', 'subregion_id', 'latitude', 'longitude']].sum()
countries_df_sum
# Out:
#                            region_id  subregion_id   latitude  longitude
# name
# Afghanistan                      3.0          14.0  33.000000       65.0
# Aland Islands                    4.0          18.0  60.116667       19.9
# Albania                          4.0          16.0  41.000000       20.0
# Algeria                          1.0           1.0  28.000000        3.0
# American Samoa                   5.0          22.0 -14.333333     -170.0
# ...                              ...           ...        ...        ...
# Wallis And Futuna Islands        5.0          22.0 -13.300000     -176.2
# Western Sahara                   1.0           1.0  24.500000      -13.0
# Yemen                            3.0          11.0  15.000000       48.0
# Zambia                           1.0           4.0 -15.000000       30.0
# Zimbabwe                         1.0           4.0 -20.000000       30.0
#
# [250 rows x 4 columns]

# %%
covid_data_df = pd.read_csv('country_wise_latest.csv')
covid_data_df
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0            10             18                3.50                  69.49
# 1             6             63                2.95                  56.25
# 2             8            749                4.16                  67.34
# 3             0              0                5.73                  88.53
# 4             1              0                4.32                  25.47
# ..          ...            ...                 ...                    ...
# 182           2              0                0.73                  35.33
# 183           0              0               10.00                  80.00
# 184           4             36               28.56                  49.26
# 185           1            465                3.08                  61.84
# 186           2             24                1.33                  20.04
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                      5.04                35526            737
# 1                      5.25                 4171            709
# 2                      6.17                23691           4282
# 3                      6.48                  884             23
# 4                     16.94                  749            201
# ..                      ...                  ...            ...
# 182                    2.08                 8916           1705
# 183                   12.50                   10              0
# 184                   57.98                 1619             72
# 185                    4.97                 3326           1226
# 186                    6.64                 1713            991
#
#      1 week % increase             WHO Region
# 0                 2.07  Eastern Mediterranean
# 1                17.00                 Europe
# 2                18.07                 Africa
# 3                 2.60                 Europe
# 4                26.84                 Africa
# ..                 ...                    ...
# 182              19.12  Eastern Mediterranean
# 183               0.00                 Africa
# 184               4.45  Eastern Mediterranean
# 185              36.86                 Africa
# 186              57.85                 Africa
#
# [187 rows x 15 columns]

# %%
total_test_missing = covid_data_df.Active.isna()
total_test_missing
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 182    False
# 183    False
# 184    False
# 185    False
# 186    False
# Name: Active, Length: 187, dtype: bool

# %%
# merged data set

combined_df = countries_df.merge(covid_data_df, left_on='name', right_on='Country/Region')
combined_df
# Out:
#       id            name iso3 iso2  numeric_code phone_code           capital  \
# 0      1     Afghanistan  AFG   AF             4         93             Kabul
# 1      3         Albania  ALB   AL             8        355            Tirana
# 2      4         Algeria  DZA   DZ            12        213           Algiers
# 3      6         Andorra  AND   AD            20        376  Andorra la Vella
# 4      7          Angola  AGO   AO            24        244            Luanda
# ..   ...             ...  ...  ...           ...        ...               ...
# 162  240         Vietnam  VNM   VN           704         84             Hanoi
# 163  244  Western Sahara  ESH   EH           732        212          El-Aaiun
# 164  245           Yemen  YEM   YE           887        967             Sanaa
# 165  246          Zambia  ZMB   ZM           894        260            Lusaka
# 166  247        Zimbabwe  ZWE   ZW           716        263            Harare
#
#     currency    currency_name currency_symbol  ... New cases New deaths  \
# 0        AFN   Afghan afghani               ؋  ...       106         10
# 1        ALL     Albanian lek             Lek  ...       117          6
# 2        DZD   Algerian dinar              دج  ...       616          8
# 3        EUR             Euro               €  ...        10          0
# 4        AOA   Angolan kwanza              Kz  ...        18          1
# ..       ...              ...             ...  ...       ...        ...
# 162      VND  Vietnamese đồng               ₫  ...        11          0
# 163      MAD  Moroccan Dirham             MAD  ...         0          0
# 164      YER      Yemeni rial               ﷼  ...        10          4
# 165      ZMW   Zambian kwacha              ZK  ...        71          1
# 166      ZWL  Zimbabwe Dollar               $  ...       192          2
#
#     New recovered  Deaths / 100 Cases Recovered / 100 Cases  \
# 0              18                3.50                 69.49
# 1              63                2.95                 56.25
# 2             749                4.16                 67.34
# 3               0                5.73                 88.53
# 4               0                4.32                 25.47
# ..            ...                 ...                   ...
# 162             0                0.00                 84.69
# 163             0               10.00                 80.00
# 164            36               28.56                 49.26
# 165           465                3.08                 61.84
# 166            24                1.33                 20.04
#
#      Deaths / 100 Recovered Confirmed last week 1 week change  \
# 0                      5.04               35526           737
# 1                      5.25                4171           709
# 2                      6.17               23691          4282
# 3                      6.48                 884            23
# 4                     16.94                 749           201
# ..                      ...                 ...           ...
# 162                    0.00                 384            47
# 163                   12.50                  10             0
# 164                   57.98                1619            72
# 165                    4.97                3326          1226
# 166                    6.64                1713           991
#
#      1 week % increase             WHO Region
# 0                 2.07  Eastern Mediterranean
# 1                17.00                 Europe
# 2                18.07                 Africa
# 3                 2.60                 Europe
# 4                26.84                 Africa
# ..                 ...                    ...
# 162              12.24        Western Pacific
# 163               0.00                 Africa
# 164               4.45  Eastern Mediterranean
# 165              36.86                 Africa
# 166              57.85                 Africa
#
# [167 rows x 38 columns]

# %%
combined_df['test_per_million'] = combined_df['Deaths / 100 Cases'] * 1e6 / combined_df['Confirmed last week']
combined_df['cases_per_million'] = combined_df['Recovered / 100 Cases'] * 1e6 / combined_df["Confirmed last week"]
combined_df['deaths_per_million'] = combined_df['Deaths / 100 Recovered'] * 1e6 / combined_df['Confirmed last week']
combined_df
# Out:
#       id            name iso3 iso2  numeric_code phone_code           capital  \
# 0      1     Afghanistan  AFG   AF             4         93             Kabul
# 1      3         Albania  ALB   AL             8        355            Tirana
# 2      4         Algeria  DZA   DZ            12        213           Algiers
# 3      6         Andorra  AND   AD            20        376  Andorra la Vella
# 4      7          Angola  AGO   AO            24        244            Luanda
# ..   ...             ...  ...  ...           ...        ...               ...
# 162  240         Vietnam  VNM   VN           704         84             Hanoi
# 163  244  Western Sahara  ESH   EH           732        212          El-Aaiun
# 164  245           Yemen  YEM   YE           887        967             Sanaa
# 165  246          Zambia  ZMB   ZM           894        260            Lusaka
# 166  247        Zimbabwe  ZWE   ZW           716        263            Harare
#
#     currency    currency_name currency_symbol  ... Deaths / 100 Cases  \
# 0        AFN   Afghan afghani               ؋  ...               3.50
# 1        ALL     Albanian lek             Lek  ...               2.95
# 2        DZD   Algerian dinar              دج  ...               4.16
# 3        EUR             Euro               €  ...               5.73
# 4        AOA   Angolan kwanza              Kz  ...               4.32
# ..       ...              ...             ...  ...                ...
# 162      VND  Vietnamese đồng               ₫  ...               0.00
# 163      MAD  Moroccan Dirham             MAD  ...              10.00
# 164      YER      Yemeni rial               ﷼  ...              28.56
# 165      ZMW   Zambian kwacha              ZK  ...               3.08
# 166      ZWL  Zimbabwe Dollar               $  ...               1.33
#
#     Recovered / 100 Cases Deaths / 100 Recovered  Confirmed last week  \
# 0                   69.49                   5.04                35526
# 1                   56.25                   5.25                 4171
# 2                   67.34                   6.17                23691
# 3                   88.53                   6.48                  884
# 4                   25.47                  16.94                  749
# ..                    ...                    ...                  ...
# 162                 84.69                   0.00                  384
# 163                 80.00                  12.50                   10
# 164                 49.26                  57.98                 1619
# 165                 61.84                   4.97                 3326
# 166                 20.04                   6.64                 1713
#
#     1 week change  1 week % increase             WHO Region test_per_million  \
# 0             737               2.07  Eastern Mediterranean        98.519394
# 1             709              17.00                 Europe       707.264445
# 2            4282              18.07                 Africa       175.594107
# 3              23               2.60                 Europe      6481.900452
# 4             201              26.84                 Africa      5767.690254
# ..            ...                ...                    ...              ...
# 162            47              12.24        Western Pacific         0.000000
# 163             0               0.00                 Africa   1000000.000000
# 164            72               4.45  Eastern Mediterranean     17640.518839
# 165          1226              36.86                 Africa       926.037282
# 166           991              57.85                 Africa       776.415645
#
#      cases_per_million  deaths_per_million
# 0         1.956032e+03        1.418679e+02
# 1         1.348597e+04        1.258691e+03
# 2         2.842430e+03        2.604365e+02
# 3         1.001471e+05        7.330317e+03
# 4         3.400534e+04        2.261682e+04
# ..                 ...                 ...
# 162       2.205469e+05        0.000000e+00
# 163       8.000000e+06        1.250000e+06
# 164       3.042619e+04        3.581223e+04
# 165       1.859290e+04        1.494287e+03
# 166       1.169877e+04        3.876241e+03
#
# [167 rows x 41 columns]

# %%
# highest test per million

highest_test_df = combined_df.sort_values('test_per_million', ascending=False).head(10)
highest_test_df
# Out:
#       id            name iso3 iso2  numeric_code phone_code  \
# 163  244  Western Sahara  ESH   EH           732        212
# 15    23          Belize  BLZ   BZ            84        501
# 12    20        Barbados  BRB   BB            52     +1-246
# 101  145          Monaco  MCO   MC           492        377
# 164  245           Yemen  YEM   YE           887        967
# 62    94          Guyana  GUY   GY           328        592
# 22    33          Brunei  BRN   BN            96        673
# 88   125   Liechtenstein  LIE   LI           438        423
# 148  215           Syria  SYR   SY           760        963
# 30    43            Chad  TCD   TD           148        235
#
#                  capital currency              currency_name currency_symbol  \
# 163             El-Aaiun      MAD            Moroccan Dirham             MAD
# 15              Belmopan      BZD              Belize dollar               $
# 12            Bridgetown      BBD           Barbadian dollar            Bds$
# 101               Monaco      EUR                       Euro               €
# 164                Sanaa      YER                Yemeni rial               ﷼
# 62            Georgetown      GYD            Guyanese dollar               $
# 22   Bandar Seri Begawan      BND              Brunei dollar              B$
# 88                 Vaduz      CHF                Swiss franc             CHf
# 148             Damascus      SYP               Syrian pound              LS
# 30             N'Djamena      XAF  Central African CFA franc            FCFA
#
#      ... Deaths / 100 Cases Recovered / 100 Cases Deaths / 100 Recovered  \
# 163  ...              10.00                 80.00                  12.50
# 15   ...               4.17                 54.17                   7.69
# 12   ...               6.36                 85.45                   7.45
# 101  ...               3.45                 89.66                   3.85
# 164  ...              28.56                 49.26                  57.98
# 62   ...               5.14                 46.53                  11.05
# 22   ...               2.13                 97.87                   2.17
# 88   ...               1.16                 94.19                   1.23
# 148  ...               5.93                  0.00                    inf
# 30   ...               8.13                 87.85                   9.26
#
#      Confirmed last week 1 week change  1 week % increase  \
# 163                   10             0               0.00
# 15                    40             8              20.00
# 12                   106             4               3.77
# 101                  109             7               6.42
# 164                 1619            72               4.45
# 62                   337            52              15.43
# 22                   141             0               0.00
# 88                    86             0               0.00
# 148                  522           152              29.12
# 30                   889            33               3.71
#
#                 WHO Region test_per_million  cases_per_million  \
# 163                 Africa   1000000.000000       8.000000e+06
# 15                Americas    104250.000000       1.354250e+06
# 12                Americas     60000.000000       8.061321e+05
# 101                 Europe     31651.376147       8.225688e+05
# 164  Eastern Mediterranean     17640.518839       3.042619e+04
# 62                Americas     15252.225519       1.380712e+05
# 22         Western Pacific     15106.382979       6.941135e+05
# 88                  Europe     13488.372093       1.095233e+06
# 148  Eastern Mediterranean     11360.153257       0.000000e+00
# 30                  Africa      9145.106862       9.881890e+04
#
#      deaths_per_million
# 163        1.250000e+06
# 15         1.922500e+05
# 12         7.028302e+04
# 101        3.532110e+04
# 164        3.581223e+04
# 62         3.278932e+04
# 22         1.539007e+04
# 88         1.430233e+04
# 148                 inf
# 30         1.041620e+04
#
# [10 rows x 41 columns]

# %%
highest_cases_df = combined_df.sort_values('cases_per_million', ascending=False).head(10)
highest_cases_df
# Out:
#       id            name iso3 iso2  numeric_code phone_code       capital  \
# 163  244  Western Sahara  ESH   EH           732        212      El-Aaiun
# 57    86       Greenland  GRL   GL           304        299          Nuuk
# 41    61        Dominica  DMA   DM           212     +1-767        Roseau
# 82   119            Laos  LAO   LA           418        856     Vientiane
# 58    87         Grenada  GRD   GD           308     +1-473  St. George's
# 127  186     Saint Lucia  LCA   LC           662     +1-758      Castries
# 15    23          Belize  BLZ   BZ            84        501      Belmopan
# 88   125   Liechtenstein  LIE   LI           438        423         Vaduz
# 17    26          Bhutan  BTN   BT            64        975       Thimphu
# 101  145          Monaco  MCO   MC           492        377        Monaco
#
#     currency             currency_name currency_symbol  ...  \
# 163      MAD           Moroccan Dirham             MAD  ...
# 57       DKK              Danish krone             Kr.  ...
# 41       XCD  Eastern Caribbean dollar               $  ...
# 82       LAK                   Lao kip               ₭  ...
# 58       XCD  Eastern Caribbean dollar               $  ...
# 127      XCD  Eastern Caribbean dollar               $  ...
# 15       BZD             Belize dollar               $  ...
# 88       CHF               Swiss franc             CHf  ...
# 17       BTN        Bhutanese ngultrum             Nu.  ...
# 101      EUR                      Euro               €  ...
#
#     Deaths / 100 Cases Recovered / 100 Cases Deaths / 100 Recovered  \
# 163              10.00                 80.00                  12.50
# 57                0.00                 92.86                   0.00
# 41                0.00                100.00                   0.00
# 82                0.00                 95.00                   0.00
# 58                0.00                100.00                   0.00
# 127               0.00                 91.67                   0.00
# 15                4.17                 54.17                   7.69
# 88                1.16                 94.19                   1.23
# 17                0.00                 86.87                   0.00
# 101               3.45                 89.66                   3.85
#
#      Confirmed last week 1 week change  1 week % increase       WHO Region  \
# 163                   10             0               0.00           Africa
# 57                    13             1               7.69           Europe
# 41                    18             0               0.00         Americas
# 82                    19             1               5.26  Western Pacific
# 58                    23             0               0.00         Americas
# 127                   23             1               4.35         Americas
# 15                    40             8              20.00         Americas
# 88                    86             0               0.00           Europe
# 17                    90             9              10.00  South-East Asia
# 101                  109             7               6.42           Europe
#
#     test_per_million  cases_per_million  deaths_per_million
# 163   1000000.000000       8.000000e+06        1.250000e+06
# 57          0.000000       7.143077e+06        0.000000e+00
# 41          0.000000       5.555556e+06        0.000000e+00
# 82          0.000000       5.000000e+06        0.000000e+00
# 58          0.000000       4.347826e+06        0.000000e+00
# 127         0.000000       3.985652e+06        0.000000e+00
# 15     104250.000000       1.354250e+06        1.922500e+05
# 88      13488.372093       1.095233e+06        1.430233e+04
# 17          0.000000       9.652222e+05        0.000000e+00
# 101     31651.376147       8.225688e+05        3.532110e+04
#
# [10 rows x 41 columns]

# %%
higest_deaths_df = combined_df.sort_values('deaths_per_million', ascending=False).head(10)
higest_deaths_df
# Out:
#       id            name iso3 iso2  numeric_code phone_code     capital  \
# 28    39          Canada  CAN   CA           124          1      Ottawa
# 148  215           Syria  SYR   SY           760        963    Damascus
# 132  196          Serbia  SRB   RS           688        381    Belgrade
# 146  213          Sweden  SWE   SE           752         46   Stockholm
# 105  150      Mozambique  MOZ   MZ           508        258      Maputo
# 163  244  Western Sahara  ESH   EH           732        212    El-Aaiun
# 15    23          Belize  BLZ   BZ            84        501    Belmopan
# 12    20        Barbados  BRB   BB            52     +1-246  Bridgetown
# 108  156     Netherlands  NLD   NL           528         31   Amsterdam
# 164  245           Yemen  YEM   YE           887        967       Sanaa
#
#     currency       currency_name currency_symbol  ... Deaths / 100 Cases  \
# 28       CAD     Canadian dollar               $  ...               7.68
# 148      SYP        Syrian pound              LS  ...               5.93
# 132      RSD       Serbian dinar             din  ...               2.25
# 146      SEK       Swedish krona              kr  ...               7.18
# 105      MZN  Mozambican metical              MT  ...               0.65
# 163      MAD     Moroccan Dirham             MAD  ...              10.00
# 15       BZD       Belize dollar               $  ...               4.17
# 12       BBD    Barbadian dollar            Bds$  ...               6.36
# 108      EUR                Euro               €  ...              11.53
# 164      YER         Yemeni rial               ﷼  ...              28.56
#
#     Recovered / 100 Cases Deaths / 100 Recovered  Confirmed last week  \
# 28                   0.00                    inf               112925
# 148                  0.00                    inf                  522
# 132                  0.00                    inf                21253
# 146                  0.00                    inf                78048
# 105                  0.00                    inf                 1507
# 163                 80.00                  12.50                   10
# 15                  54.17                   7.69                   40
# 12                  85.45                   7.45                  106
# 108                  0.35                3259.26                52132
# 164                 49.26                  57.98                 1619
#
#     1 week change  1 week % increase             WHO Region test_per_million  \
# 28           3533               3.13               Americas        68.009741
# 148           152              29.12  Eastern Mediterranean     11360.153257
# 132          2888              13.59                 Europe       105.867407
# 146          1347               1.73                 Europe        91.994670
# 105           194              12.87                 Africa       431.320504
# 163             0               0.00                 Africa   1000000.000000
# 15              8              20.00               Americas    104250.000000
# 12              4               3.77               Americas     60000.000000
# 108          1281               2.46                 Europe       221.169339
# 164            72               4.45  Eastern Mediterranean     17640.518839
#
#      cases_per_million  deaths_per_million
# 28        0.000000e+00                 inf
# 148       0.000000e+00                 inf
# 132       0.000000e+00                 inf
# 146       0.000000e+00                 inf
# 105       0.000000e+00                 inf
# 163       8.000000e+06        1.250000e+06
# 15        1.354250e+06        1.922500e+05
# 12        8.061321e+05        7.028302e+04
# 108       6.713727e+00        6.251937e+04
# 164       3.042619e+04        3.581223e+04
#
# [10 rows x 41 columns]

# %%
highest_test_per_million = combined_df.test_per_million.count()
highest_test_per_million
# Out:
# 167

# %%
highest_deaths_per_million = combined_df.deaths_per_million.count()
highest_deaths_per_million
# Out:
# 167

# %%
combined_df.columns
# Out:
# Index(['id', 'name', 'iso3', 'iso2', 'numeric_code', 'phone_code', 'capital',
#        'currency', 'currency_name', 'currency_symbol', 'tld', 'native',
#        'region', 'region_id', 'subregion', 'subregion_id', 'nationality',
#        'timezones', 'latitude', 'longitude', 'emoji', 'emojiU', 'gdp',
#        'Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New cases', 'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#        'Confirmed last week', '1 week change', '1 week % increase',
#        'WHO Region', 'test_per_million', 'cases_per_million',
#        'deaths_per_million'],
#       dtype='object')
